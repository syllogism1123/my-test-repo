# %% [markdown]
# #  Data Science Tools and Ecosystem

# %% [markdown]
# ### Introduction
# _In this notebook, Data Science Tolls and Ecosystem are summarized_

# %% [markdown]
# ### Some of popular languages that Data Scientist use are:
# 1. Python
# 2. R
# 3. C++
# 4. Java

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Spyder             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# Examples:
# - `3 + 5` # Addition
# - `12 - 4` # Subtraction
# - `6 * 7` # Multiplication
# - `16 / 2` # Division
# - `2 ** 3` # Exponentiation
# - `(3 + 5) * 2` # Combined operations using parentheses

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. Seaborn

# %%
# This a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
hours = 200 / 60
print(f"200 minutes converts to hours is equal {hours:.2f} hours")
# Out:
# 200 minutes converts to hours is equal 3.33 hours

# %% [markdown]
# ### Introduction
#
# _In this notebook, Data Science Tolls and Ecosystem are summarized_

# %% [markdown]
# **Objectives:**
# - List popular languages used for Data Science
# - Identify commonly used libraries in Data Science
# - Describe open-source development environment tools

# %% [markdown]
# ## Author
# Xin Du
